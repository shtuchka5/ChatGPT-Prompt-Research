# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
import string
from nltk.tokenize import word_tokenize, sent_tokenize
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import word_tokenize
import numpy as np
import math
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# !pip install lexical_diversity
# Out:
# Collecting lexical_diversity
#   Downloading lexical_diversity-0.1.1-py3-none-any.whl.metadata (4.1 kB)
# Downloading lexical_diversity-0.1.1-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: lexical_diversity
# Successfully installed lexical_diversity-0.1.1

# %%
from lexical_diversity import lex_div as ld

# %%
def calculate_metrics(text):
    text = text.lower()

    # Remove punctuation
    text_no_punct = text.translate(str.maketrans('', '', string.punctuation))

    # Tokenize the text
    words = word_tokenize(text_no_punct)

    stop_words = set(stopwords.words('russian'))

    # Remove stop words
    words_no_stop = [word for word in words if word not in stop_words]

    # Remove digits
    words_no_digits = [word for word in words_no_stop if not word.isdigit()]

    # Calculate metrics on cleaned text
    text_clean = ' '.join(words_no_digits)

    metrics = {}

    # 1. MLTD
    mltd = ld.mtld(words_no_digits) if len(words_no_digits) > 0 else 0
    metrics['MLTD'] = mltd

    # 2. Ratio of Content Words to Stop Words
    content_words = [word for word in words_no_digits if word not in stop_words]
    ratio_content_stop = len(content_words) / len(stop_words) if len(stop_words) > 0 else 0
    metrics['ratio_content_stop'] = ratio_content_stop

    # 3. Text Diversity Measures
    def entropy(words):
        word_freq = Counter(words)
        total_words = len(words)
        entropy = -sum((freq / total_words) * math.log2(freq / total_words) for freq in word_freq.values())
        return entropy

    def hershey_diversity(words):
        unique_words = len(set(words))
        total_words = len(words)
        return unique_words / total_words if total_words > 0 else 0

    metrics['entropy'] = entropy(words_no_digits)
    metrics['hershey_diversity'] = hershey_diversity(words_no_digits)

    return metrics

def print_report(index, metrics):
    print(f'Текст {index}.')
    print('Метрики текста:')
    for metric, value in metrics.items():
        print(f'{metric}: {value}')
    print()

def calculate_group_metrics(metrics_list, group_indices):
    group_metrics = {
        'MLTD': [],
        'ratio_content_stop': [],
        'entropy': [],
        'hershey_diversity': []
    }

    for i in group_indices:
        if i < len(metrics_list):
            metrics = metrics_list[i]
            for key in group_metrics.keys():
                if key in metrics:
                    group_metrics[key].append(metrics[key])

    average_metrics = {}
    for key, values in group_metrics.items():
        average_metrics[key] = np.mean(values) if values else 0

    return average_metrics

def main():
    with open('/content/Texts.txt', 'r', encoding='windows-1251') as f:
        text_data = f.read()

    texts = []
    current_text = ""
    for line in text_data.splitlines():
        if line.startswith("Текст"):
            if current_text:
                texts.append(current_text)
            current_text = line
        else:
            current_text += " " + line
    texts.append(current_text)  # Add the last text

    metrics_list = []
    for i, text in enumerate(texts):
        metrics = calculate_metrics(text)
        print_report(i+1, metrics)
        metrics_list.append(metrics)

    # Specify the group indices (subtract 1 for 0-based index)
    group_indices1 = [i-1 for i in [1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43]]
    group_indices2 = [i-1 for i in [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44]]
    group_indices3 = [i-1 for i in [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45]]

    # Calculate and print average metrics for specified groups
    average_metrics1 = calculate_group_metrics(metrics_list, group_indices1)
    average_metrics2 = calculate_group_metrics(metrics_list, group_indices2)
    average_metrics3 = calculate_group_metrics(metrics_list, group_indices3)

    print('Средние метрики для групп 1:')
    for metric, value in average_metrics1.items():
        print(f'{metric}: {value}')

    print('\nСредние метрики для групп 2:')
    for metric, value in average_metrics2.items():
        print(f'{metric}: {value}')

    print('\nСредние метрики для групп 3:')
    for metric, value in average_metrics3.items():
        print(f'{metric}: {value}')

if __name__ == "__main__":
    main()
# Out:
# Текст 1.
# Метрики текста:
# MLTD: 283.50000000000034
# ratio_content_stop: 0.2980132450331126
# entropy: 5.402964207440784
# hershey_diversity: 0.9555555555555556
#
# Текст 2.
# Метрики текста:
# MLTD: 65.83111111111113
# ratio_content_stop: 0.304635761589404
# entropy: 5.132257608230924
# hershey_diversity: 0.8043478260869565
#
# Текст 3.
# Метрики текста:
# MLTD: 69.63542903227022
# ratio_content_stop: 0.7615894039735099
# entropy: 5.939933829314663
# hershey_diversity: 0.6347826086956522
#
# Текст 4.
# Метрики текста:
# MLTD: 58.57144715447156
# ratio_content_stop: 0.3443708609271523
# entropy: 5.257756064128519
# hershey_diversity: 0.8076923076923077
#
# Текст 5.
# Метрики текста:
# MLTD: 134.45600000000002
# ratio_content_stop: 0.32450331125827814
# entropy: 5.410628211462147
# hershey_diversity: 0.8979591836734694
#
# Текст 6.
# Метрики текста:
# MLTD: 100.82978723404256
# ratio_content_stop: 0.7417218543046358
# entropy: 6.065074315720389
# hershey_diversity: 0.7053571428571429
#
# Текст 7.
# Метрики текста:
# MLTD: 196.63000000000005
# ratio_content_stop: 0.3509933774834437
# entropy: 5.562733897918602
# hershey_diversity: 0.9245283018867925
#
# Текст 8.
# Метрики текста:
# MLTD: 115.76444444444441
# ratio_content_stop: 0.40397350993377484
# entropy: 5.602868485103867
# hershey_diversity: 0.8524590163934426
#
# Текст 9.
# Метрики текста:
# MLTD: 415.0299999999999
# ratio_content_stop: 0.5099337748344371
# entropy: 6.162890436798801
# hershey_diversity: 0.948051948051948
#
# Текст 10.
# Метрики текста:
# MLTD: 54.88
# ratio_content_stop: 0.2781456953642384
# entropy: 4.94577248225106
# hershey_diversity: 0.7857142857142857
#
# Текст 11.
# Метрики текста:
# MLTD: 60.50153846153848
# ratio_content_stop: 0.3509933774834437
# entropy: 5.171132246934387
# hershey_diversity: 0.7547169811320755
#
# Текст 12.
# Метрики текста:
# MLTD: 82.0
# ratio_content_stop: 0.543046357615894
# entropy: 5.643779748362222
# hershey_diversity: 0.7073170731707317
#
# Текст 13.
# Метрики текста:
# MLTD: 161.83999999999997
# ratio_content_stop: 0.4503311258278146
# entropy: 5.799085775449803
# hershey_diversity: 0.8823529411764706
#
# Текст 14.
# Метрики текста:
# MLTD: 134.56
# ratio_content_stop: 0.3841059602649007
# entropy: 5.582118926162053
# hershey_diversity: 0.8793103448275862
#
# Текст 15.
# Метрики текста:
# MLTD: 63.0
# ratio_content_stop: 0.41721854304635764
# entropy: 5.304827098474515
# hershey_diversity: 0.6984126984126984
#
# Текст 16.
# Метрики текста:
# MLTD: 123.70399999999995
# ratio_content_stop: 0.31125827814569534
# entropy: 5.341822894230832
# hershey_diversity: 0.8936170212765957
#
# Текст 17.
# Метрики текста:
# MLTD: 104.04000000000003
# ratio_content_stop: 0.33774834437086093
# entropy: 5.397915538049931
# hershey_diversity: 0.8627450980392157
#
# Текст 18.
# Метрики текста:
# MLTD: 88.60727272727276
# ratio_content_stop: 0.39072847682119205
# entropy: 5.4630686849183885
# hershey_diversity: 0.8135593220338984
#
# Текст 19.
# Метрики текста:
# MLTD: 112.00000000000003
# ratio_content_stop: 0.26490066225165565
# entropy: 5.121928094887363
# hershey_diversity: 0.9
#
# Текст 20.
# Метрики текста:
# MLTD: 134.54000000000002
# ratio_content_stop: 0.4105960264900662
# entropy: 5.6516981248681075
# hershey_diversity: 0.8709677419354839
#
# Текст 21.
# Метрики текста:
# MLTD: 108.0
# ratio_content_stop: 0.7152317880794702
# entropy: 5.999094419705681
# hershey_diversity: 0.7129629629629629
#
# Текст 22.
# Метрики текста:
# MLTD: 90.71999999999997
# ratio_content_stop: 0.23841059602649006
# entropy: 4.926733681937769
# hershey_diversity: 0.8888888888888888
#
# Текст 23.
# Метрики текста:
# MLTD: 182.06999999999988
# ratio_content_stop: 0.33774834437086093
# entropy: 5.51556259687346
# hershey_diversity: 0.9215686274509803
#
# Текст 24.
# Метрики текста:
# MLTD: 158.75999999999993
# ratio_content_stop: 0.41721854304635764
# entropy: 5.743075359973515
# hershey_diversity: 0.8888888888888888
#
# Текст 25.
# Метрики текста:
# MLTD: 104.04000000000003
# ratio_content_stop: 0.33774834437086093
# entropy: 5.343898136046725
# hershey_diversity: 0.8627450980392157
#
# Текст 26.
# Метрики текста:
# MLTD: 121.37999999999998
# ratio_content_stop: 0.33774834437086093
# entropy: 5.437131224324441
# hershey_diversity: 0.8823529411764706
#
# Текст 27.
# Метрики текста:
# MLTD: 50.169234472797314
# ratio_content_stop: 0.543046357615894
# entropy: 5.582847279796984
# hershey_diversity: 0.7073170731707317
#
# Текст 28.
# Метрики текста:
# MLTD: 0.0
# ratio_content_stop: 0.09933774834437085
# entropy: 3.906890595608518
# hershey_diversity: 1.0
#
# Текст 29.
# Метрики текста:
# MLTD: 223.99999999999983
# ratio_content_stop: 0.26490066225165565
# entropy: 5.221928094887364
# hershey_diversity: 0.95
#
# Текст 30.
# Метрики текста:
# MLTD: 92.61000000000001
# ratio_content_stop: 0.41721854304635764
# entropy: 5.572362859939174
# hershey_diversity: 0.8095238095238095
#
# Текст 31.
# Метрики текста:
# MLTD: 106.47000000000004
# ratio_content_stop: 0.2582781456953642
# entropy: 5.060917923934979
# hershey_diversity: 0.8974358974358975
#
# Текст 32.
# Метрики текста:
# MLTD: 206.1733333333334
# ratio_content_stop: 0.31125827814569534
# entropy: 5.384376085720193
# hershey_diversity: 0.9361702127659575
#
# Текст 33.
# Метрики текста:
# MLTD: 58.464629609366455
# ratio_content_stop: 0.6158940397350994
# entropy: 5.398533004284212
# hershey_diversity: 0.5483870967741935
#
# Текст 34.
# Метрики текста:
# MLTD: 271.0400000000003
# ratio_content_stop: 0.2913907284768212
# entropy: 5.368522527728205
# hershey_diversity: 0.9545454545454546
#
# Текст 35.
# Метрики текста:
# MLTD: 38.85818181818182
# ratio_content_stop: 0.2582781456953642
# entropy: 4.6632313853624945
# hershey_diversity: 0.717948717948718
#
# Текст 36.
# Метрики текста:
# MLTD: 44.653163152053274
# ratio_content_stop: 0.6291390728476821
# entropy: 5.407712155763494
# hershey_diversity: 0.5368421052631579
#
# Текст 37.
# Метрики текста:
# MLTD: 47.78666666666667
# ratio_content_stop: 0.2119205298013245
# entropy: 4.625
# hershey_diversity: 0.8125
#
# Текст 38.
# Метрики текста:
# MLTD: 52.87568267749615
# ratio_content_stop: 0.45695364238410596
# entropy: 5.055927493255115
# hershey_diversity: 0.5652173913043478
#
# Текст 39.
# Метрики текста:
# MLTD: 64.0
# ratio_content_stop: 0.847682119205298
# entropy: 5.8076611612099125
# hershey_diversity: 0.546875
#
# Текст 40.
# Метрики текста:
# MLTD: 68.72444444444443
# ratio_content_stop: 0.31125827814569534
# entropy: 5.123425819624651
# hershey_diversity: 0.8085106382978723
#
# Текст 41.
# Метрики текста:
# MLTD: 71.0
# ratio_content_stop: 0.47019867549668876
# entropy: 5.480595358880354
# hershey_diversity: 0.704225352112676
#
# Текст 42.
# Метрики текста:
# MLTD: 44.72923408845739
# ratio_content_stop: 0.9668874172185431
# entropy: 5.806459768406013
# hershey_diversity: 0.5136986301369864
#
# Текст 43.
# Метрики текста:
# MLTD: 121.37999999999998
# ratio_content_stop: 0.33774834437086093
# entropy: 5.422329508595744
# hershey_diversity: 0.8823529411764706
#
# Текст 44.
# Метрики текста:
# MLTD: 182.30153846153854
# ratio_content_stop: 0.609271523178808
# entropy: 6.211008831033507
# hershey_diversity: 0.8586956521739131
#
# Текст 45.
# Метрики текста:
# MLTD: 82.79807692307693
# ratio_content_stop: 0.7218543046357616
# entropy: 6.0754340953794275
# hershey_diversity: 0.7064220183486238
#
# Средние метрики для групп 1:
# MLTD: 120.08577055103886
# ratio_content_stop: 0.2922737306843267
# entropy: 5.147318773985571
# hershey_diversity: 0.8837626221123872
#
# Средние метрики для групп 2:
# MLTD: 121.89012202050957
# ratio_content_stop: 0.3708609271523179
# entropy: 5.394558680743223
# hershey_diversity: 0.8305790058014194
#
# Средние метрики для групп 3:
# MLTD: 101.55245514928912
# ratio_content_stop: 0.6158940397350994
# entropy: 5.731516947869825
# hershey_diversity: 0.698559891886095
